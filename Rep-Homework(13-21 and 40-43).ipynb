# %% [markdown]
# ## Exercise 13

# %%
from sys import argv
first, second, third = argv
script = argv

print ("The script is called:",script)
print("Your first variable is:",first)
print("Your second variable is:",second)
print("Your third variable is:",third)
# Out:
# The script is called: ['C:\\Users\\walte\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\walte\\AppData\\Roaming\\jupyter\\runtime\\kernel-5c6911c0-8975-4e5f-9936-c1a6fd2b7e04.json']
# Your first variable is: C:\Users\walte\Anaconda3\lib\site-packages\ipykernel_launcher.py
# Your second variable is: -f
# Your third variable is: C:\Users\walte\AppData\Roaming\jupyter\runtime\kernel-5c6911c0-8975-4e5f-9936-c1a6fd2b7e04.json

# %% [markdown]
# That messages are the "directions" that I use to program, the main direction is that I use to enter to Python and the variables are the other ways to program.

# %% [markdown]
# ## Exercise 14

# %%
from sys import argv
user_name = argv
script = argv
prompt = '>'

print(f"Hi {user_name},I´m the {script}script")
print("I'd like to ask you a few questions.")
print(f"Are you okay with me {user_name}?")
likes = input(prompt)

print(f"Where do you live {user_name}?")
lives = input(prompt)

print("What kind of computer do you have?")
computer = input(prompt)

print(f"""Alrigth, so you said {likes} about liking me.
You live in {lives}. It´s a good place, I think.
And you have a {computer} computer. It's a good one.
""")
# Out:
# Hi ['C:\\Users\\walte\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\walte\\AppData\\Roaming\\jupyter\\runtime\\kernel-5c6911c0-8975-4e5f-9936-c1a6fd2b7e04.json'],I´m the ['C:\\Users\\walte\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\walte\\AppData\\Roaming\\jupyter\\runtime\\kernel-5c6911c0-8975-4e5f-9936-c1a6fd2b7e04.json']script
# I'd like to ask you a few questions.
# Are you okay with me ['C:\\Users\\walte\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\walte\\AppData\\Roaming\\jupyter\\runtime\\kernel-5c6911c0-8975-4e5f-9936-c1a6fd2b7e04.json']?
# >Yes
# Where do you live ['C:\\Users\\walte\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\walte\\AppData\\Roaming\\jupyter\\runtime\\kernel-5c6911c0-8975-4e5f-9936-c1a6fd2b7e04.json']?
# >Monte Alto
# What kind of computer do you have?
# >HP
# Alrigth, so you said Yes about liking me.
# ...

# %% [markdown]
# In this program, it ask you for some information about you and then tell you with your answers a message of your personal information.

# %% [markdown]
# ## Exercise 15

# %%
from sys import argv
filename = argv

script = argv
txt = open(filename)

print(f"Here's your file {filename}:")
print(txt.read())

print("Type of filename again:")
file_again = input(">")

txt_again = open(file_again)

print(txt_again.read())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-78629f61a0c2> in <module>
#       3
#       4 script = argv
# ----> 5 txt = open(filename)
#       6
#       7 print(f"Here's your file {filename}:")
#
# TypeError: expected str, bytes or os.PathLike object, not list

# %% [markdown]
# I use JupyterLab to run it, I save with the same program in a txt, but with the extension ".py" and another with the text that I want to see, if you don't have the files saved in Python, it's going to tell you that it doesn´t exist.
#
# ![Captura%20de%20pantalla%20%2873%29.png](attachment:Captura%20de%20pantalla%20%2873%29.png)

# %% [markdown]
# ## Exercise 16

# %%
from sys import argv
script = argv
filename = argv

print(f"We're going to erase {filename}.")
print("If you don't want that, hit CTRL+C (^C).")
print("If you do want that, hit RETURN.")

input ("?")

print("Opening the file...")
target = open(filename, 'w')

print("Truncating the file. Goodbye!")
target.truncate()

print("Now I'm going to ask you for three lines.")

line1 = input("Line 1:")
line2 = input("Line 2:")
line3 = input("Line 3:")

print("I'm going to write these to the file.")

target.write(line1)
target.write("\n\"")
target.write(line2)
target.write("\n\"")
target.write(line3)
target.write("\n\"")

print("And finally, we close it.")
target.close()
# Out:
# We're going to erase ['C:\\Users\\walte\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\walte\\AppData\\Roaming\\jupyter\\runtime\\kernel-5c6911c0-8975-4e5f-9936-c1a6fd2b7e04.json'].
# If you don't want that, hit CTRL+C (^C).
# If you do want that, hit RETURN.
# ?
# Opening the file...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-3c7b1a5ebc43> in <module>
#      10
#      11 print("Opening the file...")
# ---> 12 target = open(filename, 'w')
#      13
#      14 print("Truncating the file. Goodbye!")
#
# TypeError: expected str, bytes or os.PathLike object, not list

# %% [markdown]
# The difference with the other is to eliminate the file that you don't want it.
# ![Captura%20de%20pantalla%20%2874%29.png](attachment:Captura%20de%20pantalla%20%2874%29.png)

# %% [markdown]
# ## Exercise 17

# %%
from sys import argv
from os.path import exists

from_file = argv
to_file = argv
script = argv
print(f"Copying from {from_file} to {to_file}")

in_file = open(from_file)
indata = in_file.read()

print(f"The input file is {len(indata)} bytes long")

print(f"Does the output file exist? {exists(to_file)}")
print("Ready, hit RETURN to continue, CTRL+C to abort")
input()
out_file = open(to_file, 'w')
out_file.write(indata)

print("Alright, all done")

out_file.close()
in_file.close()
# Out:
# Copying from ['C:\\Users\\walte\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\walte\\AppData\\Roaming\\jupyter\\runtime\\kernel-5c6911c0-8975-4e5f-9936-c1a6fd2b7e04.json'] to ['C:\\Users\\walte\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\walte\\AppData\\Roaming\\jupyter\\runtime\\kernel-5c6911c0-8975-4e5f-9936-c1a6fd2b7e04.json']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-4a0b0558d149> in <module>
#       7 print(f"Copying from {from_file} to {to_file}")
#       8
# ----> 9 in_file = open(from_file)
#      10 indata = in_file.read()
#      11
#
# TypeError: expected str, bytes or os.PathLike object, not list

# %% [markdown]
# And in this one is to copy a text of a file to another new file.
# ![Captura%20de%20pantalla%20%2875%29.png](attachment:Captura%20de%20pantalla%20%2875%29.png)

# %% [markdown]
# ## Exercise 18

# %%
def print_two(*args):
    arg1, arg2 = args
    print(f"arg1: {arg1}, arg2: {arg2}")

def print_two_again(arg1, arg2):
    print(f"arg1: {arg1}, arg2: {arg2}:")

def print_one(arg1):
    print(f"arg1: {arg1}")

def print_none():
    print("I got nothing.")
    
print_two("Zed","Shaw")
print_two_again("Zed","Shaw")
print_one("First!")
print_none()
# Out:
# arg1: Zed, arg2: Shaw
# arg1: Zed, arg2: Shaw:
# arg1: First!
# I got nothing'.

# %% [markdown]
# This program is about all the variables that I used in that moment

# %% [markdown]
# ## Exercise 19

# %%
def cheese_and_crackers(cheese_count, boxes_of_crackers):
    print(f"You have {cheese_count} cheeses!")
    print(f"You have {boxes_of_crackers} boxes of crackers!")
    print("Man that's enough for a party!")
    print("Get a blanket.\n")
    
print("We can just give the function numbers directly:")
cheese_and_crackers(20, 30)

print("OR, we can use variables from our script")
amount_of_cheese = 10
amount_of_crackers = 50

print("We can even do math inside too:")
cheese_and_crackers(10 + 20, 5 + 6)

print("And we can combine the two variables and math:")
cheese_and_crackers(amount_of_cheese + 100, amount_of_cheese + 1000)
# Out:
# We can just give the function numbers directly:
# You have 20 cheeses!
# You have 30 boxes of crackers!
# Man that's enough for a party!
# Get a blanket.
#
# OR, we can use variables from our script
# We can even do math inside too:
# You have 30 cheeses!
# You have 11 boxes of crackers!
# Man that's enough for a party!
# Get a blanket.
#
# And we can combine the two variables and math:
# You have 110 cheeses!
# You have 1010 boxes of crackers!
# Man that's enough for a party!
# Get a blanket.

# %% [markdown]
# These are mathematic functions expressed in programmation language and is easier to calculate the total products that you can have.

# %% [markdown]
# ## Exercise 20

# %%
from sys import argv
script = argv
input_file = argv

def print_all(f):
    print(f.read())

def rewind(f):
    f.seek(0)

def print_a_line(line_count, f):
    print(line_count, f.readline())

current_file = open(input_file)

print("First let's print the whole file: \n")

print_all(current_file)

print("Let's print two lines:")

current_line = 1
print_a_line(current_line, current_file)

current_line = current_line + 1
print_a_line(current_line, current_file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-103a5643602b> in <module>
#      12     print(line_count, f.readline())
#      13
# ---> 14 current_file = open(input_file)
#      15
#      16 print("First let's print the whole file: \n")
#
# TypeError: expected str, bytes or os.PathLike object, not list

# %% [markdown]
# ## Exercise 21

# %%
def add(x, y):
    print(f"ADDING {x} + {y}")
    return x + y

def substract(x, y):
    print(f"SUBSTRACTING {x} - {y}")
    return x - y

def multiply(x, y):
    print(f"MULTIPLYING {x} / {y}")
    return x * y

def divide(x, y):
    print(f"DIVIDING {x} / {y}")
    return x / y

print("Let's do some math with just functions!")

age = add(30, 5)
height = substract(78, 4)
weight = multiply(90, 2)
iq = divide(100, 2)

print(f"Age: {age}, Height: {height}, Weight: {weight}, IQ {iq}")

print("Here's a puzzle.")

what = add(age, substract(height, multiply(weight, divide(iq,2))))
print("That becomes:",what,"Can you do it by hand?")
# Out:
# Let's do some math with just functions!
# ADDING 30 + 5
# SUBSTRACTING 78 - 4
# MULTIPLYING 90 / 2
# DIVIDING 100 / 2
# Age: 35, Height: 74, Weight: 180, IQ 50.0
# Here's a puzzle.
# DIVIDING 50.0 / 2
# MULTIPLYING 180 / 25.0
# SUBSTRACTING 74 - 4500.0
# ADDING 35 + -4426.0
# That becomes: -4391.0 Can you do it by hand?

# %% [markdown]
# This is a way to have the calculations previously of the problems and you can change it to have a different result.

# %% [markdown]
# ## Exercise 40

# %%
class name:
    def __init__(self,age):
        self.age = age

        
        
    def speak(self,message): 
        print(message)

Walter = name(19)
Nava = name(20)
print(f"I'm Walter and I'm {Walter.age} years old")
print(f"I'm Nava and I'm {Nava.age} years old")

Walter.speak("Hi Walter, how are you?")
Nava.speak(f"Hello, Nava")
# Out:
# I'm Walter and I'm 19 years old
# I'm Nava and I'm 20 years old
# Hi Walter, how are you?
# Hello, Nava

# %% [markdown]
# This is a way to make a particular "list" that you want to order it.

# %% [markdown]
# ## Exercise 41

# %%
import random  
from urllib.request import urlopen
import sys
WORD_URL = "http://learncodethehardway.org/words.txt"
WORDS = []
PHRASES = {
            "class %%%(%%%):":
           "Make a class named %%% that is-a %%%.",
           "class %%%(object):\n\tdef __init__(self, ***)" :
           "class %%% has-a __init__ that takes self and *** params.",
           "class %%%(object):\n\tdef ***(self, @@@)":
           "class %%% has-a function *** that takes self and @@@ params.",
           "*** = %%%()":
           "Set *** to an instance of class %%%.",
           "***.***(@@@)":
           "From *** get the *** function, call it with params self, @@@.",
           "***.*** = '***'":
           "From *** get the *** attribute and set it to '***'." 
}
 
if len(sys.argv) == 2 and sys.argv[1] == "english":
    PHRASE_FIRST = True 
else: 
    PHRASE_FIRST = False


for word in urlopen(WORD_URL).readlines():
    WORDS.append(str(word.strip(), encoding="utf-8"))

def convert(snippet, phrase): 
    class_names = [w.capitalize() for w in
                   random.sample(WORDS, snippet.count("%%%"))]
    other_names = random.sample(WORDS, snippet.count("***"))
    results = []
    param_names = []
    
    for i in range(0, snippet.count("@@@")):
        param_count = random.randint(1,3)
        param_names.append(', '.join(
            random.sample(WORDS, param_count)))
    for sentence in snippet, phrase:
        result = sentence[:]
        
# fake class names 
        for word in class_names:
            result = result.replace("%%%", word, 1)
    
# fake other names
        for word in other_names: 
            result = result.replace("***", word, 1)
    
 
        for word in param_names:
            result = result.replace("@@@", word, 1)
    
        results.append(result)
    return results


try:
    while True:
        snippets = list(PHRASES.keys())
        random.shuffle(snippets)
        
        for snippet in snippets:
            phrase = PHRASES[snippet] 
            question, answer = convert(snippet, phrase)
            if PHRASE_FIRST:
                question, answer = answer, question
            print(question)
            input("> ") 
            print(f"ANSWER: {answer}\n\n")
except EOFError:
    print("\nBye")
# Out:
# bridge.butto(dust, card)
# > dust
# ANSWER: From bridge get the butto function, call it with params self, dust, card.
#
#
# class Birthday(object):
# 	def __init__(self, appliance)
# > appliance
# ANSWER: class Birthday has-a __init__ that takes self and appliance params.
#
#
# class Dad(Desk):
# > desm
# ANSWER: Make a class named Dad that is-a Desk.
#
#
# argument = Disgust()

# %% [markdown]
# It refers to the form of the structure that you can write the way of the data.

# %% [markdown]
# ## Exercise 42

# %%
class Animal(object):
    pass
## ??
class Dog(Animal):
    def __init__(self, name): 
        ## ??
        self.name = name
## ??
class Cat(Animal):
    
    def __init__(self, name):
        ## ??
        self.name = name
## ??
class Person(object):
    def __init__(self, name):
        ## ??

        self.name = name
        ## Person has-a pet of some kind
        self.pet = None
## ??
class Employee(Person):
    def __init__(self, name, salary):
        ## ?? hmm what is this strange magic?
        super(Employee, self).__init__(name)
        ## ?? 
        self.salary = salary
## ?? 
class Fish(object):
    pass
## ??
class Salmon(Fish):
    pass

## ??
class Halibut(Fish):
    pass

## rover is-a Dog
rover = Dog("Rover")
## ??
satan = Cat("Satan")
## ??
mary = Person("Mary")
## ?? 
mary.pet = satan
## ?? 
frank = Employee("Frank", 120000)
## ?? 
frank.pet = rover
## ?? 
flipper = Fish()
## ?? 
crouse = Salmon()
## ?? 
harry = Halibut()

# %% [markdown]
# This is for take the differences between some animals with other ones, I am refering on the example.

# %% [markdown]
# ## Exercise 43

# %%
class Scene(object):
    def enter(self):
        pass

class Engine(object):
    def _init_(self, scene_map):
        pass
    def play(self):
        pass
    
class Death(Scene):
    def enter(self):
        pass
    
class CentralCorridor(Scene):
    def enter(self):
        print(dedent(""" 
            The Gothons of Planet Percal #25 have invaded your ship and 
            destroyed your entire crew. You are the last surviving 
            member and your last mission is to get the neutron destruct 
            bomb from the Weapons Armory, put it in the bridge, and 
            blow the ship up after getting into an escape pod.
             You're running down the central corridor to the Weapons 
             Armory when a Gothon jumps out, red scaly skin, dark grimy 
             teeth, and evil clown costume flowing around his hate 
             filled body. He's blocking the door to the Armory and
         about to pull a weapon to blast you. 
         """))
        action = input("> ")
        if action == "shoot!": 
            print(dedent("""
        
        Quick on the draw you yank out your blaster and fire 
        it at the Gothon. His clown costume is flowing and 
        moving around his body, which throws off your aim. 
        Your laser hits his costume but misses him entirely. 
        This completely ruins his brand new costume his mother 
        bought him, which makes him fly into an insane rage 
        and blast you repeatedly in the face until you are 
        dead. Then he eats you. 
        """)) 
        
            return 'death'
        elif action == "dodge!":
            print(dedent("""
        Like a world class boxer you dodge, weave, slip and 
        slide right as the Gothon's blaster cranks a laser 
        past your head. In the middle of your artful dodge 
        your foot slips and you bang your head on the metal 
        wall and pass out. You wake up shortly after only to 
        die as the Gothon stomps on your head and eats you. 
        """)) 
            return 'death'
        elif action == "tell a joke":
            print(dedent("""
        Lucky for you they made you learn Gothon insults in 
        the academy. You tell the one Gothon joke you know: 
        Lbhe zbgure vf fb sng, jura fur fvgf nebhaq gur ubhfr, 
        fur fvgf nebhaq gur ubhfr. The Gothon stops, tries 
        not to laugh, then busts out laughing and can't move. 
        While he's laughing you run up and shoot him square in 
        the head putting him down, then jump through the 
        Weapon Armory door. 
        """)) 
            return 'laser_weapon_armory'
        else: 
            print("DOES NOT COMPUTE!") 
            return 'central_corridor'

# %% [markdown]
# This is similar like the previous program, but the difference is that the analysisis for a real problem, not for differences of some animals.
