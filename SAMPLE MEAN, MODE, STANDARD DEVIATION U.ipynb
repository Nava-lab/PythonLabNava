# %%
Option =int(input("Choose the option: \nSample mean (1), \nMode (2), \nStandard desviation (3) "))
if Option ==1:
    print("SAMPLE MEAN")

Sample_mean=0
SUM = 0
n = int(input("Capture the number of the data you want: "))
c = 0

while c < n:
    m= int(input("Capture the number: "))
    SUM = SUM + m
    c = c + 1
    
Sample_mean= SUM / n
print ("The Sample mean is: " , Sample_mean)


if Option ==2:
    print("MODE")

List = []
Sum = 0
for i in range(10):
    value = int(input("Insert the number of %i: "%(i+1)))
    List.insert(i,value)
    Sum = Sum+value
    
mode = []
In_value = List.count(List[0])
for i in range(10):
    var = List[i]
    r_value = List.count(var)
    if(r_value > In_value):
        In_value = r_value
        mode = []
        mode.insert(0,var)
    elif(r_value == In_value and var not in mode):
        In_value = r_value
        mode.insert(i,var)
#--------------------------------------------------------------------
List.sort()
print("\nList in order= ", List)

var1=0
var2=0
var3=0
var4=0
valpzero = List.count(List[0])
valpQ = List.count(List[5])
for i in range(10):
    h = List.count(List[i])
    if h == 2:
        var1 = var1+1
    elif  h == 10:
            var2 = var2+1
    elif  h == 1:
            var3 = var3+1
    else:
            var4 = var4+1

if var1==10 or var2==10 or var3==10 or (valpzero==5 and valpQ==5):
    print("\nMode doesn't exist")
else:
    print("\nMode: ",mode)
    
print("\nSum: ",Sum)
print("\nMedia: ",Sum/10)


if Option ==3:
    print("STANDARD DEVIATION")

List = []
Sum_x = 0
S_var = 0
S_m = 0
dx = []
n=int(input("Insert the range of the values: "))
for i in range(0,n):
    x=int(input("Introduce the values of x: "))
Sum_x+=x
S_m=Sum_x/n
S_var+=((x-S_m)**2)/(n-1)
Std_dev_list=S_var**(1/2)
print("The standard deviation is: " , Std_dev_list)
# Out:
# Choose the option:
# Sample mean (1),
# Mode (2),
# Standard desviation (3) 1
# SAMPLE MEAN
# Capture the number of the data you want: 3
# Capture the number: 2
# Capture the number: 4
# Capture the number: 5
# The Sample mean is:  3.6666666666666665
# Insert the number of 1: 5
# Insert the number of 2: 6
# Insert the number of 3: 3
# Insert the number of 4: 4
# Insert the number of 5: 7
# Insert the number of 6: 8
# Insert the number of 7: 3
# Insert the number of 8: 3
# Insert the number of 9: 5
# Insert the number of 10: 6
#
# List in order=  [3, 3, 3, 4, 5, 5, 6, 6, 7, 8]
#
# Mode:  [3]
#
# Sum:  50
#
# Media:  5.0
# Insert the range of the values: 5
# Introduce the values of x: 2
# Introduce the values of x: 4
# Introduce the values of x: 5
# Introduce the values of x: 67
# Introduce the values of x: 4
# The standard deviation is:  1.6
